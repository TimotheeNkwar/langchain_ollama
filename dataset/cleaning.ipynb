# %%
import pandas as pd
data = pd.read_csv("TMDB_movie_dataset_v11.csv")
data.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
data.describe()
# Out:
#                  id  vote_average    vote_count       revenue       runtime  \
# count  1.338165e+06  1.338165e+06  1.338165e+06  1.338165e+06  1.338165e+06
# mean   8.542149e+05  1.634372e+00  1.603327e+01  6.348789e+05  4.495636e+01
# std    4.543083e+05  2.901830e+00  2.936260e+02  1.872763e+07  6.095650e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01 -2.800000e+01
# 25%    4.710890e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    8.692520e+05  0.000000e+00  0.000000e+00  0.000000e+00  1.700000e+01
# 75%    1.255363e+06  3.000000e+00  1.000000e+00  0.000000e+00  8.600000e+01
# max    1.599061e+06  1.000000e+01  3.449500e+04  5.000000e+09  1.440000e+04
#
#              budget    popularity
# count  1.338165e+06  1.338165e+06
# mean   2.452982e+05  1.071566e+00
# std    5.154494e+06  7.004499e+00
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e-01
# 50%    0.000000e+00  6.000000e-01
# 75%    0.000000e+00  7.890000e-01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338165 entries, 0 to 1338164
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1338165 non-null  int64
#  1   title                 1338148 non-null  object
#  2   vote_average          1338165 non-null  float64
#  3   vote_count            1338165 non-null  int64
#  4   status                1338165 non-null  object
#  5   release_date          1062752 non-null  object
#  6   revenue               1338165 non-null  int64
#  7   runtime               1338165 non-null  int64
#  8   adult                 1338165 non-null  bool
#  9   backdrop_path         338720 non-null   object
#  10  budget                1338165 non-null  int64
#  11  homepage              138693 non-null   object
#  12  imdb_id               649718 non-null   object
#  13  original_language     1338165 non-null  object
# ...
